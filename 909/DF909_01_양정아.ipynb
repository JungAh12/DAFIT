# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
#cv2.filter2D
#0~1 사이 값으로 구성된 3x3 커널을 생성한 뒤 이미지에 적용한 두 이미지를 동시에 출력해보자.
#이미지에 적용전 높이 너비를 256,256이고 gray로 변환한다.
img_path = '/content/drive/My Drive/다핏문제/909/lena.jpg'
img = cv2.imread(img_path,2)

# %%
img = cv2.resize(img,(256,256))
print(img.shape)
cv2_imshow(img)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256 at 0x7F30C063A630>

# %%
kernel = np.random.rand(3,3)
after_img = cv2.filter2D(img,-1,kernel)
cv2_imshow(after_img)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F30C063AC18>
