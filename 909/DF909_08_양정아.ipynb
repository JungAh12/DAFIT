# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#edge는 픽셀값이 급격하게 변하는 지점이다.
#주변보다 1차 미분값이 큰 부분을 엣지로 검출하게된다.
#sobel x,y 방향 각각의 별도 커널을 사용해서 엣지 검출한다.
#sobel x는 수직선 방향
#sobel y는 수평선 방향
import cv2
from google.colab.patches import cv2_imshow

# %%
img_path='/content/drive/My Drive/다핏문제/909/lena.jpg'

# %%
img = cv2.imread(img_path,2)
res = cv2.Sobel(img,-1,1,1,ksize=3)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F5F81D77400>

# %%
img = cv2.imread(img_path,2)
res = cv2.Laplacian(img,-1,ksize=1)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F5F81D773C8>

# %%
img = cv2.imread(img_path,2)
res = cv2.Canny(img,100,250)    #low, high threshold에 따라 달라짐
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F5F813C1240>
