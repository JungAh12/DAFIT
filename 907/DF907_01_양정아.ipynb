# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
img_path = '/content/drive/My Drive/다핏문제/907/DF907_01_01.jpg'
#3채널로 이미지 읽기
img3 = cv.imread(img_path, flags=1)

# %%
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F4BA8AAD9E8>

# %%
img1 = cv.imread(img_path, flags=0)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F4BA8B75860>

# %%
cv.waitKey(0)
cv.imwrite('/content/drive/My Drive/다핏문제/907/lena.jpg',img3)
cv.imwrite('/content/drive/My Drive/다핏문제/907/lena.png',img3)
cv.imwrite('/content/drive/My Drive/다핏문제/907/lena.bmp',img3)
# Out:
# True
