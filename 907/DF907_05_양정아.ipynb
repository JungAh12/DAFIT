# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img_path = '/content/drive/My Drive/다핏문제/907/lena.jpg'

# %%
img = cv2.imread(img_path,1)
print('origin')
cv2_imshow(img)
v_img = cv2.flip(img, 1)
print('\n\nvertical flip')
cv2_imshow(v_img)
h_img = cv2.flip(img, 0)
print('\n\nhorizontal flip')
cv2_imshow(h_img)
vh_img = cv2.flip(v_img, 0)
print('\n\nvertical horizontal flip')
cv2_imshow(vh_img)
# Out:
# origin
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F6B72A6BA20>
# vertical flip
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F6B72A6BA20>
# horizontal flip
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F6B72A6BAC8>
# vertical horizontal flip
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F6B72A6BA20>
