# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
img_path = '/content/drive/My Drive/다핏문제/907/lena.jpg'

# %%
# OpenCV의 가산혼합의 삼원색 기본 순서는 BGR이다.

img_bgr = cv.imread(img_path,1)
img_rgb = cv.cvtColor(img_rgb, cv.COLOR_BGR2RGB)
cv2_imshow(img_bgr)
cv2_imshow(img_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F845A7063C8>
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F845A706390>

# %%
b,g,r = cv.split(img_bgr)
img_rbg = cv.merge((r,b,g))

# %%
cv2_imshow(img_rbg)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F845A706048>
