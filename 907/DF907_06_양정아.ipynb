# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img_path = '/content/drive/My Drive/다핏문제/907/lena.jpg'

# %%
img = cv2.imread(img_path,1)
height, width = img.shape[:2]

# %%
down_img = cv2.resize(img,(height//2,width//2))

# %%
cv2_imshow(down_img)
# Out:
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7FCB7BD7B2E8>

# %%
up_img = cv2.resize(img, (height*2, width*2))

# %%
cv2_imshow(up_img)
# Out:
# <PIL.Image.Image image mode=RGB size=450x450 at 0x7FCB7BD7B278>

# %%
img_list = []
for i in range(100):
    img_list.append(cv2.resize(img,(height+i,width+i)))

# %%
cv2_imshow(img_list[0])
cv2_imshow(img_list[-1])
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FCB7F7BB6D8>
# <PIL.Image.Image image mode=RGB size=324x324 at 0x7FCB7BD7B470>

# %%
sh = cv2.resize(img, None, fx=5, fy=5, interpolation=cv2.INTER_AREA)
cv2_imshow(sh)
sh1 = cv2.resize(img, None, fx=5, fy=5, interpolation=cv2.INTER_CUBIC)
cv2_imshow(sh1)
sh2 = cv2.resize(img, None, fx=5, fy=5, interpolation=cv2.INTER_LINEAR)
cv2_imshow(sh2)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
